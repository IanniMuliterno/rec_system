# %%
import pandas as pd
import numpy as np
import matplotlib as mtb
import seaborn as sns

# %%
user = pd.read_csv('data/BX-Users.csv',error_bad_lines=False,sep = ';',encoding='latin-1')
books = pd.read_csv('data/BX-Books.csv',error_bad_lines=False,sep = ';',encoding='latin-1')
ratings = pd.read_csv('data/BX-Book-Ratings.csv',error_bad_lines=False,sep = ';',encoding='latin-1') 

user.head()
# Out:
# C:\Users\IM_py\AppData\Local\Temp\ipykernel_22432\531460213.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   user = pd.read_csv('data/BX-Users.csv',error_bad_lines=False,sep = ';',encoding='latin-1')
# C:\Users\IM_py\AppData\Local\Temp\ipykernel_22432\531460213.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   books = pd.read_csv('data/BX-Books.csv',error_bad_lines=False,sep = ';',encoding='latin-1')
# b'Skipping line 6452: expected 8 fields, saw 9\nSkipping line 43667: expected 8 fields, saw 10\nSkipping line 51751: expected 8 fields, saw 9\n'
# b'Skipping line 92038: expected 8 fields, saw 9\nSkipping line 104319: expected 8 fields, saw 9\nSkipping line 121768: expected 8 fields, saw 9\n'
# ...

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
user.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.shape
# Out:
# (1149780, 3)

# %%
user.shape
# Out:
# (278858, 3)

# %%
books.shape
# Out:
# (271360, 8)

# %%
books_final = ratings.merge(books, on = 'ISBN').merge(user, on = 'User-ID')

# %%
books_final.columns
# Out:
# Index(['User-ID', 'ISBN', 'Book-Rating', 'Book-Title', 'Book-Author',
#        'Year-Of-Publication', 'Publisher', 'Image-URL-S', 'Image-URL-M',
#        'Image-URL-L', 'Location', 'Age'],
#       dtype='object')

# %%
titulos = ['userid','isbn','rating','title','author','year_publi','publisher','img_urls','img_urlm','img_urll','location','age']
books_final.columns = titulos
books_final
# Out:
#          userid        isbn  rating  \
# 0        276725  034545104X       0
# 1          2313  034545104X       5
# 2          2313  0812533550       9
# 3          2313  0679745580       8
# 4          2313  0060173289       9
# ...         ...         ...     ...
# 1031131  276442  2862749796       7
# 1031132  276618  3788097000       5
# 1031133  276647  0553571001       0
# 1031134  276647  0689822294      10
# 1031135  276660  0583307841       8
#
#                                                      title  \
# 0                                     Flesh Tones: A Novel
# 1                                     Flesh Tones: A Novel
# 2            Ender's Game (Ender Wiggins Saga (Paperback))
# 3                    In Cold Blood (Vintage International)
# 4         Divine Secrets of the Ya-Ya Sisterhood : A Novel
# ...                                                    ...
# 1031131                                            Le Huit
# ...

# %%
books_final.isna().sum()
# Out:
# userid             0
# isbn               0
# rating             0
# title              0
# author             1
# year_publi         0
# publisher          2
# img_urls           0
# img_urlm           0
# img_urll           4
# location           0
# age           277835
# dtype: int64

# %% [markdown]
# checking duplicates per keys

# %%
books_final.groupby(['userid','title']).ngroups
# Out:
# 1026358

# %%
books_final.shape
# Out:
# (1031136, 12)

# %% [markdown]
# the code above means that sometimes the same title has different isbns, so we need to remove that

# %%
books_final.drop_duplicates(['userid','title'],inplace=True)

# %%
aux = books_final['userid'].value_counts() > 100
aux
# Out:
# 11676      True
# 198711     True
# 98391      True
# 153662     True
# 35859      True
#           ...
# 145268    False
# 42332     False
# 4002      False
# 78202     False
# 276660    False
# Name: userid, Length: 92106, dtype: bool

# %% [markdown]
# After filtering to keep only the users who rated more than 10 books, lets see the proportion of remaining books in the analysis.

# %%
aux_index = aux[aux].index
len(books_final[books_final['userid'].isin(aux_index)]['isbn'].value_counts())/len(books_final['isbn'].value_counts())
# Out:
# 0.7339522359495135

# %%
np.sum(books_final['userid'].value_counts() >= 1)
# Out:
# 92106

# %%
books_final = books_final[books_final['userid'].isin(aux_index)]
rating_count = books_final.groupby('title')['rating'].count().reset_index()

# %% [markdown]
# Considering only books that got at least 30 ratings

# %%
rating_count = rating_count[rating_count['rating'] >= 50]

# %%
books_final = books_final.merge(rating_count,on ='title')

# %%
books_final
# Out:
#        userid        isbn  rating_x                      title  \
# 0        6543  0316666343         0  The Lovely Bones: A Novel
# 1       23768  0316666343         7  The Lovely Bones: A Novel
# 2       28523  0316666343         0  The Lovely Bones: A Novel
# 3       81977  0316666343         7  The Lovely Bones: A Novel
# 4       98391  0316666343         9  The Lovely Bones: A Novel
# ...       ...         ...       ...                        ...
# 93420   47316  0446603929         7           See How They Run
# 93421   41455  0446603929         0           See How They Run
# 93422  163973  0446603929         8           See How They Run
# 93423  151702  0446603929         0           See How They Run
# 93424  250936  0446603929         0           See How They Run
#
#                 author year_publi      publisher  \
# 0         Alice Sebold       2002  Little, Brown
# 1         Alice Sebold       2002  Little, Brown
# 2         Alice Sebold       2002  Little, Brown
# ...

# %% [markdown]
# Lets pivot the table in order to get a matrix of books X readers

# %%
books_final_T = books_final.pivot_table(columns=['userid'],index=['title'],values='rating_x')

# %%
books_final_T
# Out:
# userid                                              254     507     882     \
# title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     0.0     NaN
# 2010: Odyssey Two                                      NaN     NaN     NaN
# 204 Rosewood Lane                                      NaN     NaN     NaN
# 24 Hours                                               NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
books_final_T.fillna(0,inplace = True)

# %%
books_final_T
# Out:
# userid                                              254     507     882     \
# title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 24 Hours                                               0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...
